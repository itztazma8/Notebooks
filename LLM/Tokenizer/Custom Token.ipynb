# %% [markdown]
# ##### Token Initialization

# %%
import pandas as pd
df=pd.read_csv('PoetryFoundationData.csv')
df.columns

col1=df['Poem']
entry=col1[0]

import re
text=re.split(r'(\s)', entry)
#Removing spaces

new_list=[]
for i in text:
    new=i.strip()
    if new!="":
        new_list.append(new)

print(new_list)
new_list.sort()
# Out:
# ['Dog', 'bone,', 'stapler,', 'cribbage', 'board,', 'garlic', 'press', 'because', 'this', 'window', 'is', 'loose—lacks', 'suction,', 'lacks', 'grip.', 'Bungee', 'cord,', 'bootstrap,', 'dog', 'leash,', 'leather', 'belt', 'because', 'this', 'window', 'had', 'sash', 'cords.', 'They', 'frayed.', 'They', 'broke.', 'Feather', 'duster,', 'thatch', 'of', 'straw,', 'empty', 'bottle', 'of', "Elmer's", 'glue', 'because', 'this', 'window', 'is', 'loud—its', 'hinges', 'clack', 'open,', 'clack', 'shut.', 'Stuffed', 'bear,', 'baby', 'blanket,', 'single', 'crib', 'newel', 'because', 'this', 'window', 'is', 'split.', "It's", 'dividing', 'in', 'two.', 'Velvet', 'moss,', 'sagebrush,', 'willow', 'branch,', "robin's", 'wing', 'because', 'this', 'window,', "it's", 'pane-less.', "It's", 'only', 'a', 'frame', 'of', 'air.']

# %% [markdown]
# ##### Token ID

# %%
id={}
for i in range(len(new_list)):
    id.update({new_list[i]:i})

print(id)
# Out:
# {'Dog': 0, 'bone,': 1, 'stapler,': 2, 'cribbage': 3, 'board,': 4, 'garlic': 5, 'press': 6, 'because': 75, 'this': 76, 'window': 61, 'is': 62, 'loose—lacks': 11, 'suction,': 12, 'lacks': 13, 'grip.': 14, 'Bungee': 15, 'cord,': 16, 'bootstrap,': 17, 'dog': 18, 'leash,': 19, 'leather': 20, 'belt': 21, 'had': 25, 'sash': 26, 'cords.': 27, 'They': 30, 'frayed.': 29, 'broke.': 31, 'Feather': 32, 'duster,': 33, 'thatch': 34, 'of': 84, 'straw,': 36, 'empty': 37, 'bottle': 38, "Elmer's": 40, 'glue': 41, 'loud—its': 46, 'hinges': 47, 'clack': 50, 'open,': 49, 'shut.': 51, 'Stuffed': 52, 'bear,': 53, 'baby': 54, 'blanket,': 55, 'single': 56, 'crib': 57, 'newel': 58, 'split.': 63, "It's": 80, 'dividing': 65, 'in': 66, 'two.': 67, 'Velvet': 68, 'moss,': 69, 'sagebrush,': 70, 'willow': 71, 'branch,': 72, "robin's": 73, 'wing': 74, 'window,': 77, "it's": 78, 'pane-less.': 79, 'only': 81, 'a': 82, 'frame': 83, 'air.': 85}

# %% [markdown]
# ##### Tokenizer

# %%
class tokenizer:
    def __init__(self, dic):
        self.dic=dic

        dic1={}
        for i,j in dic.items():
            dic1.update({j:i})

        self.inverse_dic=dic1
    
    def encode(self, txt):
        text=re.split(r'([,:?;]|\s)', txt)
        id=[]
        for i in text:
            j=i.strip()
            if j!="":
                id.append(self.dic[j])
        
        return id
    
    def decode(self, id):
        st=""
        for i in range(len(id)):
            if id==len(id)-1:
                st=st+self.inverse_dic[id[i]]
            else:
                st=st+self.inverse_dic[id[i]]+" "
        
        return st

token1=tokenizer(id)
entry=token1.encode("It's a Dog")
final=token1.decode(entry)
print(final)
# Out:
# It's a Dog
